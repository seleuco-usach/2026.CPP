# %% [markdown]
# Connected to base (Python 3.12.4)

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import numpy as np
from gspread_dataframe import set_with_dataframe

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import numpy as np
from gspread_dataframe import set_with_dataframe

# Configurar el alcance y credenciales
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('/home/xenomorfo/Descargas/bamboo-sweep-465617-i4-06b9bd6f36a5.json', scope)
client = gspread.authorize(credentials)
#jose-hoyos-usach-cl@bamboo-sweep-465617-i4.iam.gserviceaccount.com 
#https://docs.google.com/spreadsheets/d/17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E/edit?gid=1818427118#gid=1818427118
# Abrir la hoja de cálculo por ID
spreadsheet = client.open_by_key('17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E')
credentials = ServiceAccountCredentials.\
from_json_keyfile_name('/home/xenomorfo/Descargas/bamboo-sweep-465617-i4-06b9bd6f36a5.json', scope)
# Abrir la hoja de cálculo por ID


CPP_DR = (
gspread.authorize(credentials)
.open_by_key('17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E')
.get_worksheet(0)
.get_all_values()
# índice 0 es la primera hoja
)



CPP_DR = pd.DataFrame(CPP_DR[1:], columns=CPP_DR[0])

CPP_DR['ANHO_PLAN'] = CPP_DR['ANHO'] +'-'+ CPP_DR['COD_PLAN2']
CPP_DR['ANHO_SIES'] = CPP_DR['ANHO'] +'-'+ CPP_DR['SIES']


CPP_DR

CPP_CARO = (
gspread.authorize(credentials)
.open_by_key('17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E')
.worksheet("CPP_CARO_2")
.get_all_values()
# índice 0 es la primera hoja
)
CPP_CARO = pd.DataFrame(CPP_CARO[2:], columns=CPP_CARO[0])

CPP_DR['ANHO_PLAN'].astype(str)
CPP_CARO['ANHO_PLAN'].astype(str)



#CPP_DR['ANHO_PLAN'].isin(CPP_CARO['ANHO_PLAN']).astype(int)

#CPP_CARO['ANHO_PLAN'].isin(CPP_DR['ANHO_PLAN']).astype(int)
CPP_DR.drop_duplicates()
# Out:
#              ID COD_PLAN  ANHO           ANHO_SIES  \
# 0     2025-3701     3701  2025    2025-I71S1C2J1V1
# 1     2025-3711     3711  2025    2025-I71S1C2J1V1
# 2     2025-7330     7330  2025  2025-I71S1C913J1V1
# 3     2025-4601     4601  2025   2025-I71S1C39J1V1
# 4     2025-4602     4602  2025   2025-I71S1C39J1V1
# ...         ...      ...   ...                 ...
# 7785  2024-9107     9107  2024   2024-I71S1C66J2V1
# 7786  2024-9137     9137  2024   2024-I71S1C56J1V2
# 7787  2021-9484     9484  2021  2021-I71S1C221J2V1
# 7788  2022-9193     9193  2022  2022-I71S1C398J2V1
# 7789  2025-9728     9728  2025  2025-I71S1C280J3V1
#
#                                             PLAN_NOMBRE JORNADA_USACH  \
# 0                                ADMINISTRACIÓN PÚBLICA             1
# 1                            ADMINISTRACIÓN PÚBLICA (D)             1
# 2            ANÁLISIS Y GESTIÓN DE PROCESOS PRODUCTIVOS             0
# 3             LICENCIATURA EN CIENCIA DE LA COMPUTACIÓN             1
# 4     ANALISTA EN COMPUTACIÓN CIENTÍFICA/LICENCIATUR...             1
# ...                                                 ...           ...
# 7785                     MAGÍSTER EN TELECOMUNICACIONES
# 7786              MAGÍSTER EN CIENCIAS DE LA INGENIERÍA
# 7787                              MAGÍSTER EN EDUCACIÓN
# 7788  MAGÍSTER EN SEGURIDAD, PERITAJE Y AUDITORÍA EN...
# 7789          MÁSTER INTEGRADO EN DISEÑO ARQUITECTÓNICO
#
#      JORNADA_SIES ESTADO_JORNADA     LLAVE           SIES  ... COD_FAC_  \
# 0               1             OK  37012025    I71S1C2J1V1  ...       60
# 1               1             OK  37112025    I71S1C2J1V1  ...       60
# 2               1             NO  73302025  I71S1C913J1V1  ...       65
# 3               1             OK  46012025   I71S1C39J1V1  ...       50
# 4               1             OK  46022025   I71S1C39J1V1  ...       50
# ...           ...            ...       ...            ...  ...      ...
# 7785                                         I71S1C66J2V1  ...
# 7786                                         I71S1C56J1V2  ...
# 7787                                        I71S1C221J2V1  ...
# 7788                                        I71S1C398J2V1  ...
# 7789                                        I71S1C280J3V1  ...
#
#                               depto                    FACULTAD_ COD_FAC  \
# 0     DPTO DE GEST Y POLÍTIC PÚBLIC  FACULTAD DE ADMS Y ECONOMÍA      60
# 1     DPTO DE GEST Y POLÍTIC PÚBLIC  FACULTAD DE ADMS Y ECONOMÍA      60
# 2        DPTO DE TECNOLOGÍAS GRALES         FACULTAD TECNOLÓGICA      65
# 3      DPTO MATEMÁT Y CS DE LA COMP          FACULTAD DE CIENCIA      50
# 4      DPTO MATEMÁT Y CS DE LA COMP          FACULTAD DE CIENCIA      50
# ...                             ...                          ...     ...
# 7785                                                                  40
# 7786                                                                  40
# 7787                                                                  55
# 7788                                                                  40
# 7789                                                                  94
#
#      comparacion_facultad                                        FACULTAD  \
# 0                    TRUE           Facultad de Administración y Economía
# 1                    TRUE           Facultad de Administración y Economía
# 2                    TRUE                            Facultad Tecnológica
# 3                    TRUE                             Facultad de Ciencia
# 4                    TRUE                             Facultad de Ciencia
# ...                   ...                                             ...
# 7785                FALSE                          Facultad de Ingeniería
# 7786                FALSE                          Facultad de Ingeniería
# 7787                FALSE                         Facultad de Humanidades
# 7788                FALSE                          Facultad de Ingeniería
# 7789                FALSE  Facultad de Arquitectura y Ambiente Construido
#
#      COD_DEPTO_2_CR                                    nombre_depto_cr  \
# 0                64       Departamento de Gestión y Políticas Públicas
# 1                64       Departamento de Gestión y Políticas Públicas
# 2                67             Departamento de Tecnologias de Gestión
# 3                51  Departamento de Matemática y Ciencia de la Com...
# 4                51  Departamento de Matemática y Ciencia de la Com...
# ...             ...                                                ...
# 7785             41               Departamento de Ingeniería Eléctrica
# 7786             47   Departamento de Ingeniería Química y Bioprocesos
# 7787             59                          Departamento de Educación
# 7788             40                             Facultad de Ingeniería
# 7789             94     Facultad de Arquitectura y Ambiente Construido
#
#      comparacion_cod_depto  ANHO_PLAN
# 0                     TRUE  2025-3701
# 1                     TRUE  2025-3711
# 2                     TRUE  2025-7330
# 3                     TRUE  2025-4601
# 4                     TRUE  2025-4602
# ...                    ...        ...
# 7785                        2024-9107
# 7786                        2024-9137
# 7787                        2021-9484
# 7788                        2022-9193
# 7789                        2025-9728
#
# [7775 rows x 30 columns]

# %%
CPP_DR.to_csv("CPP_DR.csv", index=False)

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import numpy as np
from gspread_dataframe import set_with_dataframe

# Configurar el alcance y credenciales
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('/home/xenomorfo/Descargas/bamboo-sweep-465617-i4-06b9bd6f36a5.json', scope)
client = gspread.authorize(credentials)
#jose-hoyos-usach-cl@bamboo-sweep-465617-i4.iam.gserviceaccount.com 
#https://docs.google.com/spreadsheets/d/17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E/edit?gid=1818427118#gid=1818427118
# Abrir la hoja de cálculo por ID
spreadsheet = client.open_by_key('17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E')
# Abrir la hoja de cálculo por ID


CPP_DR = (
gspread.authorize(credentials)
.open_by_key('17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E')
.get_worksheet(0)
.get_all_values()
# índice 0 es la primera hoja
)

CPP_DR = pd.DataFrame(CPP_DR[1:], columns=CPP_DR[0])

CPP_DR['ANHO_PLAN'] = CPP_DR['ANHO'] +'-'+ CPP_DR['COD_PLAN2']
CPP_DR['ANHO_SIES'] = CPP_DR['ANHO'] +'-'+ CPP_DR['SIES']


CPP_CARO = (
gspread.authorize(credentials)
.open_by_key('17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E')
.worksheet("CPP_CARO_2")
.get_all_values()
# índice 0 es la primera hoja
)
CPP_CARO = pd.DataFrame(CPP_CARO[2:], columns=CPP_CARO[0])

CPP_DR['ANHO_PLAN'].astype(str)
CPP_CARO['ANHO_PLAN'].astype(str)

CPP_DR.drop_duplicates()
# Out:
#              ID COD_PLAN  ANHO           ANHO_SIES  \
# 0     2025-3701     3701  2025    2025-I71S1C2J1V1
# 1     2025-3711     3711  2025    2025-I71S1C2J1V1
# 2     2025-7330     7330  2025  2025-I71S1C913J1V1
# 3     2025-4601     4601  2025   2025-I71S1C39J1V1
# 4     2025-4602     4602  2025   2025-I71S1C39J1V1
# ...         ...      ...   ...                 ...
# 7786  2024-9137     9137  2024   2024-I71S1C56J1V2
# 7787  2021-9484     9484  2021  2021-I71S1C221J2V1
# 7788  2022-9193     9193  2022  2022-I71S1C398J2V1
# 7789  2025-9728     9728  2025  2025-I71S1C280J3V1
# 7790               TODOS                         -
#
#                                             PLAN_NOMBRE JORNADA_USACH  \
# 0                                ADMINISTRACIÓN PÚBLICA             1
# 1                            ADMINISTRACIÓN PÚBLICA (D)             1
# 2            ANÁLISIS Y GESTIÓN DE PROCESOS PRODUCTIVOS             0
# 3             LICENCIATURA EN CIENCIA DE LA COMPUTACIÓN             1
# 4     ANALISTA EN COMPUTACIÓN CIENTÍFICA/LICENCIATUR...             1
# ...                                                 ...           ...
# 7786              MAGÍSTER EN CIENCIAS DE LA INGENIERÍA
# 7787                              MAGÍSTER EN EDUCACIÓN
# 7788  MAGÍSTER EN SEGURIDAD, PERITAJE Y AUDITORÍA EN...
# 7789          MÁSTER INTEGRADO EN DISEÑO ARQUITECTÓNICO
# 7790
#
#      JORNADA_SIES ESTADO_JORNADA     LLAVE           SIES  ... COD_FAC_  \
# 0               1             OK  37012025    I71S1C2J1V1  ...       60
# 1               1             OK  37112025    I71S1C2J1V1  ...       60
# 2               1             NO  73302025  I71S1C913J1V1  ...       65
# 3               1             OK  46012025   I71S1C39J1V1  ...       50
# 4               1             OK  46022025   I71S1C39J1V1  ...       50
# ...           ...            ...       ...            ...  ...      ...
# 7786                                         I71S1C56J1V2  ...
# 7787                                        I71S1C221J2V1  ...
# 7788                                        I71S1C398J2V1  ...
# 7789                                        I71S1C280J3V1  ...
# 7790                                                       ...
#
#                               depto                    FACULTAD_ COD_FAC  \
# 0     DPTO DE GEST Y POLÍTIC PÚBLIC  FACULTAD DE ADMS Y ECONOMÍA      60
# 1     DPTO DE GEST Y POLÍTIC PÚBLIC  FACULTAD DE ADMS Y ECONOMÍA      60
# 2        DPTO DE TECNOLOGÍAS GRALES         FACULTAD TECNOLÓGICA      65
# 3      DPTO MATEMÁT Y CS DE LA COMP          FACULTAD DE CIENCIA      50
# 4      DPTO MATEMÁT Y CS DE LA COMP          FACULTAD DE CIENCIA      50
# ...                             ...                          ...     ...
# 7786                                                                  40
# 7787                                                                  55
# 7788                                                                  40
# 7789                                                                  94
# 7790
#
#      comparacion_facultad                                        FACULTAD  \
# 0                    TRUE           Facultad de Administración y Economía
# 1                    TRUE           Facultad de Administración y Economía
# 2                    TRUE                            Facultad Tecnológica
# 3                    TRUE                             Facultad de Ciencia
# 4                    TRUE                             Facultad de Ciencia
# ...                   ...                                             ...
# 7786                FALSE                          Facultad de Ingeniería
# 7787                FALSE                         Facultad de Humanidades
# 7788                FALSE                          Facultad de Ingeniería
# 7789                FALSE  Facultad de Arquitectura y Ambiente Construido
# 7790
#
#      COD_DEPTO_2_CR                                    nombre_depto_cr  \
# 0                64       Departamento de Gestión y Políticas Públicas
# 1                64       Departamento de Gestión y Políticas Públicas
# 2                67             Departamento de Tecnologias de Gestión
# 3                51  Departamento de Matemática y Ciencia de la Com...
# 4                51  Departamento de Matemática y Ciencia de la Com...
# ...             ...                                                ...
# 7786             47   Departamento de Ingeniería Química y Bioprocesos
# 7787             59                          Departamento de Educación
# 7788             40                             Facultad de Ingeniería
# 7789             94     Facultad de Arquitectura y Ambiente Construido
# 7790
#
#      comparacion_cod_depto  ANHO_PLAN
# 0                     TRUE  2025-3701
# 1                     TRUE  2025-3711
# 2                     TRUE  2025-7330
# 3                     TRUE  2025-4601
# 4                     TRUE  2025-4602
# ...                    ...        ...
# 7786                        2024-9137
# 7787                        2021-9484
# 7788                        2022-9193
# 7789                        2025-9728
# 7790                                -
#
# [7776 rows x 30 columns]

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import numpy as np
from gspread_dataframe import set_with_dataframe

# Configurar el alcance y credenciales
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('/home/xenomorfo/Descargas/bamboo-sweep-465617-i4-06b9bd6f36a5.json', scope)
client = gspread.authorize(credentials)
#jose-hoyos-usach-cl@bamboo-sweep-465617-i4.iam.gserviceaccount.com 
#https://docs.google.com/spreadsheets/d/17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E/edit?gid=1818427118#gid=1818427118
# Abrir la hoja de cálculo por ID
spreadsheet = client.open_by_key('17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E')
# Abrir la hoja de cálculo por ID


CPP_DR = (
gspread.authorize(credentials)
.open_by_key('17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E')
.get_worksheet(0)
.get_all_values()
# índice 0 es la primera hoja
)

CPP_DR = pd.DataFrame(CPP_DR[1:], columns=CPP_DR[0])

CPP_DR['ANHO_PLAN'] = CPP_DR['ANHO'] +'-'+ CPP_DR['COD_PLAN2']
CPP_DR['ANHO_SIES'] = CPP_DR['ANHO'] +'-'+ CPP_DR['SIES']


CPP_CARO = (
gspread.authorize(credentials)
.open_by_key('17LhWP9zmDMxmyqkmlB-PTc8kf7_p6LcFHdCGAhEvi9E')
.worksheet("CPP_CARO_2")
.get_all_values()
# índice 0 es la primera hoja
)
CPP_CARO = pd.DataFrame(CPP_CARO[2:], columns=CPP_CARO[0])

CPP_DR['ANHO_PLAN'].astype(str)
CPP_CARO['ANHO_PLAN'].astype(str)

CPP_DR.drop_duplicates()

CPP_DR.to_csv("CPP_DR.csv", index=False)

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected
