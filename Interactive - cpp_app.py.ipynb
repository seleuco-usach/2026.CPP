# %% [markdown]
# Connected to base (Python 3.12.4)

# %%
import streamlit as st
import pandas as pd
import numpy as np

# %%
pd.read_csv("CPP_DR.csv")
# Out:
#              ID  COD_PLAN    ANHO           ANHO_SIES  \
# 0     2025-3701    3701.0  2025.0    2025-I71S1C2J1V1
# 1     2025-3711    3711.0  2025.0    2025-I71S1C2J1V1
# 2     2025-7330    7330.0  2025.0  2025-I71S1C913J1V1
# 3     2025-4601    4601.0  2025.0   2025-I71S1C39J1V1
# 4     2025-4602    4602.0  2025.0   2025-I71S1C39J1V1
# ...         ...       ...     ...                 ...
# 7785  2024-9107    9107.0  2024.0   2024-I71S1C66J2V1
# 7786  2024-9137    9137.0  2024.0   2024-I71S1C56J1V2
# 7787  2021-9484    9484.0  2021.0  2021-I71S1C221J2V1
# 7788  2022-9193    9193.0  2022.0  2022-I71S1C398J2V1
# 7789  2025-9728    9728.0  2025.0  2025-I71S1C280J3V1
#
#                                             PLAN_NOMBRE JORNADA_USACH  \
# 0                                ADMINISTRACIÓN PÚBLICA             1
# 1                            ADMINISTRACIÓN PÚBLICA (D)             1
# 2            ANÁLISIS Y GESTIÓN DE PROCESOS PRODUCTIVOS             0
# ...

# %%
tabla_cpp = pd.read_csv("CPP_DR.csv")
tabla_cpp
# Out:
#              ID  COD_PLAN    ANHO           ANHO_SIES  \
# 0     2025-3701    3701.0  2025.0    2025-I71S1C2J1V1
# 1     2025-3711    3711.0  2025.0    2025-I71S1C2J1V1
# 2     2025-7330    7330.0  2025.0  2025-I71S1C913J1V1
# 3     2025-4601    4601.0  2025.0   2025-I71S1C39J1V1
# 4     2025-4602    4602.0  2025.0   2025-I71S1C39J1V1
# ...         ...       ...     ...                 ...
# 7785  2024-9107    9107.0  2024.0   2024-I71S1C66J2V1
# 7786  2024-9137    9137.0  2024.0   2024-I71S1C56J1V2
# 7787  2021-9484    9484.0  2021.0  2021-I71S1C221J2V1
# 7788  2022-9193    9193.0  2022.0  2022-I71S1C398J2V1
# 7789  2025-9728    9728.0  2025.0  2025-I71S1C280J3V1
#
#                                             PLAN_NOMBRE JORNADA_USACH  \
# 0                                ADMINISTRACIÓN PÚBLICA             1
# 1                            ADMINISTRACIÓN PÚBLICA (D)             1
# 2            ANÁLISIS Y GESTIÓN DE PROCESOS PRODUCTIVOS             0
# ...

# %%
tabla_cpp.columns
# Out:
# Index(['ID', 'COD_PLAN', 'ANHO', 'ANHO_SIES', 'PLAN_NOMBRE', 'JORNADA_USACH',
#        'JORNADA_SIES', 'ESTADO_JORNADA', 'LLAVE', 'SIES', 'LLAVE_SIES',
#        'PROGRAMA_SIES', 'OBSERVACIÓN', 'COD_PLAN2', 'COD_CARRERA',
#        'Nombre_carrera', 'REPLICA_COD_SIES', 'DURACIÓN', 'DURACION_TOTAL',
#        'COD_DEPTO_2', 'COD_FAC_', 'depto', 'FACULTAD_', 'COD_FAC',
#        'comparacion_facultad', 'FACULTAD', 'COD_DEPTO_2_CR', 'nombre_depto_cr',
#        'comparacion_cod_depto', 'ANHO_PLAN'],
#       dtype='object')

# %%
tabla_cpp['ID','COD_PLAN', 'ANHO_PLAN', 'ANHO_SIES']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('ID', 'COD_PLAN', 'ANHO_PLAN', 'ANHO_SIES')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
tabla_cpp[['ID','COD_PLAN', 'ANHO_PLAN', 'ANHO_SIES']]
# Out:
#              ID  COD_PLAN  ANHO_PLAN           ANHO_SIES
# 0     2025-3701    3701.0  2025-3701    2025-I71S1C2J1V1
# 1     2025-3711    3711.0  2025-3711    2025-I71S1C2J1V1
# 2     2025-7330    7330.0  2025-7330  2025-I71S1C913J1V1
# 3     2025-4601    4601.0  2025-4601   2025-I71S1C39J1V1
# 4     2025-4602    4602.0  2025-4602   2025-I71S1C39J1V1
# ...         ...       ...        ...                 ...
# 7785  2024-9107    9107.0  2024-9107   2024-I71S1C66J2V1
# 7786  2024-9137    9137.0  2024-9137   2024-I71S1C56J1V2
# 7787  2021-9484    9484.0  2021-9484  2021-I71S1C221J2V1
# 7788  2022-9193    9193.0  2022-9193  2022-I71S1C398J2V1
# 7789  2025-9728    9728.0  2025-9728  2025-I71S1C280J3V1
#
# [7790 rows x 4 columns]

# %%
tabla_cpp[['ID','COD_PLAN', 'ANHO_PLAN', 'ANHO_SIES','PLAN_NOMBRE','COD_CARRERA','CARRERA_NOMBRE','ANHO']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 tabla_cpp[['ID','COD_PLAN', 'ANHO_PLAN', 'ANHO_SIES','PLAN_NOMBRE','COD_CARRERA','CARRERA_NOMBRE','ANHO']]
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
tabla_cpp[['ID','COD_PLAN', 'ANHO_PLAN', 'ANHO_SIES','PLAN_NOMBRE','COD_CARRERA','COD_FAC','FACULTAD']]
# Out:
#              ID  COD_PLAN  ANHO_PLAN           ANHO_SIES  \
# 0     2025-3701    3701.0  2025-3701    2025-I71S1C2J1V1
# 1     2025-3711    3711.0  2025-3711    2025-I71S1C2J1V1
# 2     2025-7330    7330.0  2025-7330  2025-I71S1C913J1V1
# 3     2025-4601    4601.0  2025-4601   2025-I71S1C39J1V1
# 4     2025-4602    4602.0  2025-4602   2025-I71S1C39J1V1
# ...         ...       ...        ...                 ...
# 7785  2024-9107    9107.0  2024-9107   2024-I71S1C66J2V1
# 7786  2024-9137    9137.0  2024-9137   2024-I71S1C56J1V2
# 7787  2021-9484    9484.0  2021-9484  2021-I71S1C221J2V1
# 7788  2022-9193    9193.0  2022-9193  2022-I71S1C398J2V1
# 7789  2025-9728    9728.0  2025-9728  2025-I71S1C280J3V1
#
#                                             PLAN_NOMBRE COD_CARRERA  COD_FAC  \
# 0                                ADMINISTRACIÓN PÚBLICA      ADMPUB     60.0
# 1                            ADMINISTRACIÓN PÚBLICA (D)      ADMPUB     60.0
# ...

# %%
tabla_cpp[['ID', 'ANHO_SIES','COD_PLAN', 'ANHO_PLAN', 'PLAN_NOMBRE','COD_CARRERA','COD_FAC','FACULTAD']]
# Out:
#              ID           ANHO_SIES  COD_PLAN  ANHO_PLAN  \
# 0     2025-3701    2025-I71S1C2J1V1    3701.0  2025-3701
# 1     2025-3711    2025-I71S1C2J1V1    3711.0  2025-3711
# 2     2025-7330  2025-I71S1C913J1V1    7330.0  2025-7330
# 3     2025-4601   2025-I71S1C39J1V1    4601.0  2025-4601
# 4     2025-4602   2025-I71S1C39J1V1    4602.0  2025-4602
# ...         ...                 ...       ...        ...
# 7785  2024-9107   2024-I71S1C66J2V1    9107.0  2024-9107
# 7786  2024-9137   2024-I71S1C56J1V2    9137.0  2024-9137
# 7787  2021-9484  2021-I71S1C221J2V1    9484.0  2021-9484
# 7788  2022-9193  2022-I71S1C398J2V1    9193.0  2022-9193
# 7789  2025-9728  2025-I71S1C280J3V1    9728.0  2025-9728
#
#                                             PLAN_NOMBRE COD_CARRERA  COD_FAC  \
# 0                                ADMINISTRACIÓN PÚBLICA      ADMPUB     60.0
# 1                            ADMINISTRACIÓN PÚBLICA (D)      ADMPUB     60.0
# ...

# %%
tabla_cpp[['ID', 'ANHO_SIES','COD_PLAN', 'ANHO_PLAN', 'PLAN_NOMBRE','COD_CARRERA','COD_FAC','FACULTAD','COD_DEPTO_2_CR']]
# Out:
#              ID           ANHO_SIES  COD_PLAN  ANHO_PLAN  \
# 0     2025-3701    2025-I71S1C2J1V1    3701.0  2025-3701
# 1     2025-3711    2025-I71S1C2J1V1    3711.0  2025-3711
# 2     2025-7330  2025-I71S1C913J1V1    7330.0  2025-7330
# 3     2025-4601   2025-I71S1C39J1V1    4601.0  2025-4601
# 4     2025-4602   2025-I71S1C39J1V1    4602.0  2025-4602
# ...         ...                 ...       ...        ...
# 7785  2024-9107   2024-I71S1C66J2V1    9107.0  2024-9107
# 7786  2024-9137   2024-I71S1C56J1V2    9137.0  2024-9137
# 7787  2021-9484  2021-I71S1C221J2V1    9484.0  2021-9484
# 7788  2022-9193  2022-I71S1C398J2V1    9193.0  2022-9193
# 7789  2025-9728  2025-I71S1C280J3V1    9728.0  2025-9728
#
#                                             PLAN_NOMBRE COD_CARRERA  COD_FAC  \
# 0                                ADMINISTRACIÓN PÚBLICA      ADMPUB     60.0
# 1                            ADMINISTRACIÓN PÚBLICA (D)      ADMPUB     60.0
# ...

# %%
tabla_cpp[['ID', 
           'ANHO_SIES',
           'COD_PLAN', 
           'ANHO_PLAN', 
           'PLAN_NOMBRE',
           'COD_CARRERA',
           'COD_FAC',
           'FACULTAD',
           'COD_DEPTO_2_CR', 
           'nombre_depto_cr']]
# Out:
#              ID           ANHO_SIES  COD_PLAN  ANHO_PLAN  \
# 0     2025-3701    2025-I71S1C2J1V1    3701.0  2025-3701
# 1     2025-3711    2025-I71S1C2J1V1    3711.0  2025-3711
# 2     2025-7330  2025-I71S1C913J1V1    7330.0  2025-7330
# 3     2025-4601   2025-I71S1C39J1V1    4601.0  2025-4601
# 4     2025-4602   2025-I71S1C39J1V1    4602.0  2025-4602
# ...         ...                 ...       ...        ...
# 7785  2024-9107   2024-I71S1C66J2V1    9107.0  2024-9107
# 7786  2024-9137   2024-I71S1C56J1V2    9137.0  2024-9137
# 7787  2021-9484  2021-I71S1C221J2V1    9484.0  2021-9484
# 7788  2022-9193  2022-I71S1C398J2V1    9193.0  2022-9193
# 7789  2025-9728  2025-I71S1C280J3V1    9728.0  2025-9728
#
#                                             PLAN_NOMBRE COD_CARRERA  COD_FAC  \
# 0                                ADMINISTRACIÓN PÚBLICA      ADMPUB     60.0
# 1                            ADMINISTRACIÓN PÚBLICA (D)      ADMPUB     60.0
# ...

# %%
tabla_cpp_sel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 tabla_cpp_sel
#
# NameError: name 'tabla_cpp_sel' is not defined

# %%
tabla_cpp_sel=st.selectbox("Selecciona el código a visualizar:", 
         tabla_cpp['COD_PLAN'].unique())
# Out:
# 2026-04-27 10:52:15.756 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 10:52:15.756 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 10:52:15.758 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 10:52:15.759 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 10:52:15.759 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# ...

# %%
tabla_cpp_sel
# Out:
# 3701.0

# %%
tabla_filtrada
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 tabla_filtrada
#
# NameError: name 'tabla_filtrada' is not defined

# %%
tabla_filtrada=tabla_cpp[[tabla_cpp['COD_PLAN']==tabla_cpp_sel]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 tabla_filtrada=tabla_cpp[[tabla_cpp['COD_PLAN']==tabla_cpp_sel]]
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
tabla_filtrada=tabla_cpp[[tabla_cpp['COD_PLAN']==tabla_cpp_sel]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 tabla_filtrada=tabla_cpp[[tabla_cpp['COD_PLAN']==tabla_cpp_sel]]
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
tabla_filtrada=tabla_cpp[tabla_cpp['COD_PLAN']==tabla_cpp_sel]

# %%
tabla_filtrada
# Out:
#              ID  COD_PLAN    ANHO         ANHO_SIES             PLAN_NOMBRE  \
# 0     2025-3701    3701.0  2025.0  2025-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 377   2024-3701    3701.0  2024.0  2024-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 746   2023-3701    3701.0  2023.0  2023-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 1139  2022-3701    3701.0  2022.0  2022-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 1515  2021-3701    3701.0  2021.0  2021-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 1889  2020-3701    3701.0  2020.0  2020-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 2288  2019-3701    3701.0  2019.0  2019-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 2712  2018-3701    3701.0  2018.0  2018-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 3108  2017-3701    3701.0  2017.0  2017-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 3507  2016-3701    3701.0  2016.0  2016-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 3900  2015-3701    3701.0  2015.0  2015-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# ...

# %%
programas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 programas
#
# NameError: name 'programas' is not defined

# %%
programas = tabla_cpp['COD_PLAN'].unique()

# %%
programas
# Out:
# array([3701., 3711., 7330., 4601., 4602., 4609., 5110., 5210., 5310.,
#        4260., 5031., 5032., 4110., 4111., 3605., 3607., 3611., 3613.,
#        5501., 9820., 9777., 9891., 9895., 9024., 9677., 9058., 9042.,
#        9798., 9642., 9255., 9638., 9682., 9645., 9779., 9966., 9254.,
#        9796., 9641., 9965., 9218., 9131., 9793., 9128., 9767., 9628.,
#        9043., 9130., 3900., 9632., 9625., 9780., 9057., 9844., 9825.,
#        9969., 9253., 9227., 9892., 9517., 9678., 9897., 9782., 9781.,
#        9928., 9369., 9957., 9775., 9627., 9055., 9617., 9926., 7320.,
#        7100., 9215., 9230., 9223., 9214., 9626., 9372., 9476., 9769.,
#        9124., 9109., 9110., 9256., 9186., 9776., 9410., 9411., 9479.,
#        9213., 9508., 9205., 9514., 8012., 8112., 9815., 9807., 9871.,
#        9865., 9812., 9803., 9817., 9823., 9884., 9808., 9813., 9860.,
#        9804., 9836., 9894., 9816., 9833., 9814., 9805., 9893., 9806.,
# ...

# %%
programas = tabla_cpp['COD_PLAN'].unique().dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 programas = tabla_cpp['COD_PLAN'].unique().dropna()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dropna'

# %%
programas = tabla_cpp['COD_PLAN'].unique()

# %%
programas
# Out:
# array([3701., 3711., 7330., 4601., 4602., 4609., 5110., 5210., 5310.,
#        4260., 5031., 5032., 4110., 4111., 3605., 3607., 3611., 3613.,
#        5501., 9820., 9777., 9891., 9895., 9024., 9677., 9058., 9042.,
#        9798., 9642., 9255., 9638., 9682., 9645., 9779., 9966., 9254.,
#        9796., 9641., 9965., 9218., 9131., 9793., 9128., 9767., 9628.,
#        9043., 9130., 3900., 9632., 9625., 9780., 9057., 9844., 9825.,
#        9969., 9253., 9227., 9892., 9517., 9678., 9897., 9782., 9781.,
#        9928., 9369., 9957., 9775., 9627., 9055., 9617., 9926., 7320.,
#        7100., 9215., 9230., 9223., 9214., 9626., 9372., 9476., 9769.,
#        9124., 9109., 9110., 9256., 9186., 9776., 9410., 9411., 9479.,
#        9213., 9508., 9205., 9514., 8012., 8112., 9815., 9807., 9871.,
#        9865., 9812., 9803., 9817., 9823., 9884., 9808., 9813., 9860.,
#        9804., 9836., 9894., 9816., 9833., 9814., 9805., 9893., 9806.,
# ...

# %%
programas = tabla_cpp['COD_PLAN'].unique().to_cliboard()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 programas = tabla_cpp['COD_PLAN'].unique().to_cliboard()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_cliboard'

# %%
programas = pd.DataFrame(tabla_cpp['COD_PLAN'].unique())

# %%
programas
# Out:
#           0
# 0    3701.0
# 1    3711.0
# 2    7330.0
# 3    4601.0
# 4    4602.0
# ..      ...
# 954  9293.0
# 955  9288.0
# 956  9137.0
# 957  9133.0
# 958  9728.0
#
# [959 rows x 1 columns]

# %%
programas = pd.DataFrame(tabla_cpp['COD_PLAN'].unique()).dropna()

# %%
programas
# Out:
#           0
# 0    3701.0
# 1    3711.0
# 2    7330.0
# 3    4601.0
# 4    4602.0
# ..      ...
# 954  9293.0
# 955  9288.0
# 956  9137.0
# 957  9133.0
# 958  9728.0
#
# [958 rows x 1 columns]

# %%
tabla_cpp = pd.read_csv("CPP_DR.csv")

# %%
if len(sel) == 0:
    tabla_cpp
else:
    tabla_filtrada_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 if len(sel) == 0:
#       2     tabla_cpp
#       3 else:
#
# NameError: name 'sel' is not defined

# %%
sel=st.selectbox("Selecciona el código a visualizar:", 
         tabla_cpp['COD_PLAN'].unique())
# Out:
# 2026-04-27 11:39:40.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:39:40.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:39:40.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:39:40.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:39:40.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:39:40.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:39:40.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
tabla_filtrada_2=tabla_cpp[tabla_cpp['COD_PLAN']==sel]

# %%
if len(sel) == 0:
    tabla_cpp
else:
    tabla_filtrada_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 if len(sel) == 0:
#       2     tabla_cpp
#       3 else:
#
# TypeError: object of type 'float' has no len()

# %%
sel
# Out:
# 3701.0

# %%
len(sel)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 len(sel)
#
# TypeError: object of type 'float' has no len()

# %%
len(sel).astype(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 len(sel).astype(str)
#
# TypeError: object of type 'float' has no len()

# %%
tabla_cpp['COD_PLAN'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 tabla_cpp['COD_PLAN'].astype(int)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
len(sel)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 len(sel)
#
# TypeError: object of type 'float' has no len()

# %%
tabla_cpp['COD_PLAN'] = tabla_cpp['COD_PLAN'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 tabla_cpp['COD_PLAN'] = tabla_cpp['COD_PLAN'].astype(int)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
tabla_cpp['COD_PLAN'] = tabla_cpp['COD_PLAN'].astype(str)

# %%
len(sel)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 len(sel)
#
# TypeError: object of type 'float' has no len()

# %%
sel=st.selectbox("Selecciona el código a visualizar:", 
         tabla_cpp['COD_PLAN'].unique())
# Out:
# 2026-04-27 11:42:41.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:42:41.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:42:41.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:42:41.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:42:41.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:42:41.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:42:41.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
len(sel)
# Out:
# 6

# %%
if len(sel) == 0:
    tabla_cpp
else:
    tabla_filtrada_2

# %%
len(sel)
# Out:
# 6

# %%
sel=st.selectbox("Selecciona el código a visualizar:", 
         tabla_cpp['COD_PLAN'].unique())

tabla_filtrada_2=tabla_cpp[tabla_cpp['COD_PLAN']==sel]
# Out:
# 2026-04-27 11:43:36.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:43:36.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:43:36.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:43:36.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:43:36.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:43:36.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 11:43:36.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if len(sel) == 0:
    tabla_cpp
else:
    tabla_filtrada_2

# %%
tabla_cpp
# Out:
#              ID COD_PLAN    ANHO           ANHO_SIES  \
# 0     2025-3701   3701.0  2025.0    2025-I71S1C2J1V1
# 1     2025-3711   3711.0  2025.0    2025-I71S1C2J1V1
# 2     2025-7330   7330.0  2025.0  2025-I71S1C913J1V1
# 3     2025-4601   4601.0  2025.0   2025-I71S1C39J1V1
# 4     2025-4602   4602.0  2025.0   2025-I71S1C39J1V1
# ...         ...      ...     ...                 ...
# 7785  2024-9107   9107.0  2024.0   2024-I71S1C66J2V1
# 7786  2024-9137   9137.0  2024.0   2024-I71S1C56J1V2
# 7787  2021-9484   9484.0  2021.0  2021-I71S1C221J2V1
# 7788  2022-9193   9193.0  2022.0  2022-I71S1C398J2V1
# 7789  2025-9728   9728.0  2025.0  2025-I71S1C280J3V1
#
#                                             PLAN_NOMBRE JORNADA_USACH  \
# 0                                ADMINISTRACIÓN PÚBLICA             1
# 1                            ADMINISTRACIÓN PÚBLICA (D)             1
# 2            ANÁLISIS Y GESTIÓN DE PROCESOS PRODUCTIVOS             0
# ...

# %%
tabla_cpp.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-bb617930b6f6> in ?()
# ----> 1 tabla_cpp.unique()
#
# ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
tabla_cpp.drop_duplicates()
# Out:
#              ID COD_PLAN    ANHO           ANHO_SIES  \
# 0     2025-3701   3701.0  2025.0    2025-I71S1C2J1V1
# 1     2025-3711   3711.0  2025.0    2025-I71S1C2J1V1
# 2     2025-7330   7330.0  2025.0  2025-I71S1C913J1V1
# 3     2025-4601   4601.0  2025.0   2025-I71S1C39J1V1
# 4     2025-4602   4602.0  2025.0   2025-I71S1C39J1V1
# ...         ...      ...     ...                 ...
# 7785  2024-9107   9107.0  2024.0   2024-I71S1C66J2V1
# 7786  2024-9137   9137.0  2024.0   2024-I71S1C56J1V2
# 7787  2021-9484   9484.0  2021.0  2021-I71S1C221J2V1
# 7788  2022-9193   9193.0  2022.0  2022-I71S1C398J2V1
# 7789  2025-9728   9728.0  2025.0  2025-I71S1C280J3V1
#
#                                             PLAN_NOMBRE JORNADA_USACH  \
# 0                                ADMINISTRACIÓN PÚBLICA             1
# 1                            ADMINISTRACIÓN PÚBLICA (D)             1
# 2            ANÁLISIS Y GESTIÓN DE PROCESOS PRODUCTIVOS             0
# ...

# %%
tabla_cpp = tabla_cpp.drop_duplicates()

# %%
import streamlit as st
import pandas as pd
import numpy as np

st.set_page_config(layout="wide")

tabla_cpp = pd.read_csv("CPP_DR.csv")

tabla_cpp = tabla_cpp.drop_duplicates()
# Out:
# 2026-04-27 11:51:33.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
import pandas as pd
import numpy as np

st.set_page_config(layout="wide")

tabla_cpp = pd.read_csv("CPP_DR.csv")

tabla_cpp = tabla_cpp.drop_duplicates()
# Out:
# 2026-04-27 11:51:47.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
tabla_cpp
# Out:
#              ID COD_PLAN    ANHO           ANHO_SIES  \
# 0     2025-3701     3701  2025.0    2025-I71S1C2J1V1
# 1     2025-3711     3711  2025.0    2025-I71S1C2J1V1
# 2     2025-7330     7330  2025.0  2025-I71S1C913J1V1
# 3     2025-4601     4601  2025.0   2025-I71S1C39J1V1
# 4     2025-4602     4602  2025.0   2025-I71S1C39J1V1
# ...         ...      ...     ...                 ...
# 7786  2024-9137     9137  2024.0   2024-I71S1C56J1V2
# 7787  2021-9484     9484  2021.0  2021-I71S1C221J2V1
# 7788  2022-9193     9193  2022.0  2022-I71S1C398J2V1
# 7789  2025-9728     9728  2025.0  2025-I71S1C280J3V1
# 7790        NaN    TODOS     NaN                   -
#
#                                             PLAN_NOMBRE JORNADA_USACH  \
# 0                                ADMINISTRACIÓN PÚBLICA             1
# 1                            ADMINISTRACIÓN PÚBLICA (D)             1
# 2            ANÁLISIS Y GESTIÓN DE PROCESOS PRODUCTIVOS             0
# ...

# %%
tabla_cpp['COD_PLAN'].unique()
# Out:
# array(['3701', '3711', '7330', '4601', '4602', '4609', '5110', '5210',
#        '5310', '4260', '5031', '5032', '4110', '4111', '3605', '3607',
#        '3611', '3613', '5501', '9820', '9777', '9891', '9895', '9024',
#        '9677', '9058', '9042', '9798', '9642', '9255', '9638', '9682',
#        '9645', '9779', '9966', '9254', '9796', '9641', '9965', '9218',
#        '9131', '9793', '9128', '9767', '9628', '9043', '9130', '3900',
#        '9632', '9625', '9780', '9057', '9844', '9825', '9969', '9253',
#        '9227', '9892', '9517', '9678', '9897', '9782', '9781', '9928',
#        '9369', '9957', '9775', '9627', '9055', '9617', '9926', '7320',
#        '7100', '9215', '9230', '9223', '9214', '9626', '9372', '9476',
#        '9769', '9124', '9109', '9110', '9256', '9186', '9776', '9410',
#        '9411', '9479', '9213', '9508', '9205', '9514', '8012', '8112',
#        '9815', '9807', '9871', '9865', '9812', '9803', '9817', '9823',
# ...

# %%
list(tabla_cpp['COD_PLAN'].unique())
# Out:
# ['3701',
#  '3711',
#  '7330',
#  '4601',
#  '4602',
#  '4609',
#  '5110',
#  '5210',
#  '5310',
#  '4260',
#  '5031',
#  '5032',
#  '4110',
#  '4111',
#  '3605',
#  '3607',
#  '3611',
#  '3613',
#  '5501',
#  '9820',
#  '9777',
#  '9891',
#  '9895',
#  '9024',
#  '9677',
#  '9058',
#  '9042',
#  '9798',
#  '9642',
#  '9255',
#  '9638',
#  '9682',
#  '9645',
#  '9779',
#  '9966',
#  '9254',
#  '9796',
#  '9641',
#  '9965',
#  '9218',
#  '9131',
#  '9793',
#  '9128',
#  '9767',
#  '9628',
#  '9043',
#  '9130',
#  '3900',
#  '9632',
#  '9625',
#  '9780',
#  '9057',
#  '9844',
#  '9825',
#  '9969',
#  '9253',
#  '9227',
#  '9892',
#  '9517',
#  '9678',
#  '9897',
#  '9782',
#  '9781',
#  '9928',
#  '9369',
#  '9957',
#  '9775',
#  '9627',
#  '9055',
#  '9617',
#  '9926',
#  '7320',
#  '7100',
#  '9215',
#  '9230',
#  '9223',
#  '9214',
#  '9626',
#  '9372',
#  '9476',
#  '9769',
#  '9124',
#  '9109',
#  '9110',
#  '9256',
#  '9186',
#  '9776',
#  '9410',
#  '9411',
#  '9479',
# ...

# %%
sel=st.selectbox("Selecciona el código a visualizar:", 
         list(tabla_cpp['COD_PLAN'].unique()))
# Out:
# 2026-04-27 12:05:30.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:05:30.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:05:30.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:05:30.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:05:30.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:05:30.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:05:30.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
sel
# Out:
# '3701'

# %%
tabla_filtrada_3=tabla_cpp[(tabla_cpp['COD_PLAN']==sel) & (tabla_cpp['SIES']==sel_2)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /home/xenomorfo/Documentos/ANALISTA ESTUDIOS/PEDIDOS/2026.CPP/cpp_app.py:1
# ----> 1 tabla_filtrada_3=tabla_cpp[(tabla_cpp['COD_PLAN']==sel) & (tabla_cpp['SIES']==sel_2)]
#
# NameError: name 'sel_2' is not defined

# %%
sel_2=st.selectbox("Selecciona el código a visualizar:", 
         list(tabla_filtrada_2['SIES'].unique()))
# Out:
# 2026-04-27 12:22:26.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:22:26.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:22:26.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:22:26.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:22:26.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:22:26.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 12:22:26.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
tabla_filtrada_3=tabla_cpp[(tabla_cpp['COD_PLAN']==sel) & (tabla_cpp['SIES']==sel_2)]

# %%
tabla_filtrada_3
# Out:
#              ID COD_PLAN    ANHO         ANHO_SIES             PLAN_NOMBRE  \
# 0     2025-3701     3701  2025.0  2025-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 377   2024-3701     3701  2024.0  2024-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 746   2023-3701     3701  2023.0  2023-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 1139  2022-3701     3701  2022.0  2022-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 1515  2021-3701     3701  2021.0  2021-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 1889  2020-3701     3701  2020.0  2020-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 2288  2019-3701     3701  2019.0  2019-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 2712  2018-3701     3701  2018.0  2018-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 3108  2017-3701     3701  2017.0  2017-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 3507  2016-3701     3701  2016.0  2016-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# 3900  2015-3701     3701  2015.0  2015-I71S1C2J1V1  ADMINISTRACIÓN PÚBLICA
# ...

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected
